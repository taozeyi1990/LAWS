# %%
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
dev = qml.device("default.qubit", wires=3)

# %%
def get_angles(x):

    beta0 = 2 * np.arcsin(np.sqrt(x[1] ** 2) / np.sqrt(x[0] ** 2 + x[1] ** 2 + 1e-12))
    beta1 = 2 * np.arcsin(np.sqrt(x[3] ** 2) / np.sqrt(x[2] ** 2 + x[3] ** 2 + 1e-12))
    beta2 = 2 * np.arcsin(
        np.sqrt(x[2] ** 2 + x[3] ** 2)
        / np.sqrt(x[0] ** 2 + x[1] ** 2 + x[2] ** 2 + x[3] ** 2)
    )

    return np.array([beta2, -beta1 / 2, beta1 / 2, -beta0 / 2, beta0 / 2])

# %%
def statepreparation(a):
    qml.RY(a[0], wires=0)

    qml.CNOT(wires=[0, 1])
    qml.RY(a[1], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(a[2], wires=1)

    qml.PauliX(wires=0)
    qml.CNOT(wires=[0, 1])
    qml.RY(a[3], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(a[4], wires=1)
    qml.PauliX(wires=0)

# %%
x = np.array([0.53896774, 0.79503606, 0.27826503, 0.0], requires_grad=False)
ang = get_angles(x)


@qml.qnode(dev)
def test(angles):

    statepreparation(angles)

    return qml.expval(qml.PauliZ(0))


test(ang)

print("x               : ", x)
print("angles          : ", ang)
print("amplitude vector: ", np.real(dev.state))
# Out:
# x               :  [0.53896774 0.79503606 0.27826503 0.        ]
# angles          :  [ 0.56397465 -0.          0.         -0.97504604  0.97504604]
# amplitude vector:  [ 5.38967743e-01  0.00000000e+00  7.95036065e-01  0.00000000e+00
#   2.78265032e-01  0.00000000e+00 -2.77555756e-17  0.00000000e+00]

# %%
def square_loss(labels, predictions):
    loss = 0
    for l, p in zip(labels, predictions):
        loss = loss + (l - p) ** 2

    loss = loss / len(labels)
    return loss

def accuracy(labels, predictions):

    loss = 0
    for l, p in zip(labels, predictions):
        if abs(l - p) < 1e-5:
            loss = loss + 1
    loss = loss / len(labels)

    return loss

# %%
def layer(W):
    qml.Rot(W[0, 0], W[0, 1], W[0, 2], wires=0)
    qml.Rot(W[1, 0], W[1, 1], W[1, 2], wires=1)
    qml.CNOT(wires=[0, 1])

# %%
@qml.qnode(dev)
def circuit(weights, angles):
    statepreparation(angles)

    for W in weights:
        layer(W)

    return qml.expval(qml.PauliZ(0))


def variational_classifier(weights, bias, angles):
    return circuit(weights, angles) + bias


# def cost(weights, bias, features, labels, l_features=None, l_labels=None, lookahead=False):
#     if lookahead:
#         predictions = [variational_classifier(weights, bias, f) for f in l_features]
#         return square_loss(l_labels, predictions)
#     else:
#         predictions = [variational_classifier(weights, bias, f) for f in features]
#         return square_loss(labels, predictions)
    
def cost(weights, bias, features, labels, sample_batch_size=5, feats_train=None, Y_train=None, lookahead=False):
    if lookahead:
        num_train = int(0.75 * len(Y_train))
        batch_index_lookaround = np.random.randint(0, num_train, (sample_batch_size,))
        feats_train_lookaround_batch = feats_train[batch_index_lookaround]
        Y_train_lookaround_batch = Y_train[batch_index_lookaround]
        predictions = [variational_classifier(weights, bias, f) for f in feats_train_lookaround_batch]
        return square_loss(Y_train_lookaround_batch, predictions)
    else:
        predictions = [variational_classifier(weights, bias, f) for f in features]
        return square_loss(labels, predictions)

# %%
data = np.loadtxt("./data/iris_classes1and2_scaled.txt")
X = data[:, 0:2]
print("First X sample (original)  :", X[0])

# pad the vectors to size 2^2 with constant values
padding = 0.3 * np.ones((len(X), 1))
X_pad = np.c_[np.c_[X, padding], np.zeros((len(X), 1))]
print("First X sample (padded)    :", X_pad[0])

# normalize each input
normalization = np.sqrt(np.sum(X_pad ** 2, -1))
X_norm = (X_pad.T / normalization).T
print("First X sample (normalized):", X_norm[0])

# angles for state preparation are new features
features = np.array([get_angles(x) for x in X_norm], requires_grad=False)
print("First features sample      :", features[0])

Y = data[:, -1]
# Out:
# First X sample (original)  : [0.4  0.75]
# First X sample (padded)    : [0.4  0.75 0.3  0.  ]
# First X sample (normalized): [0.44376016 0.83205029 0.33282012 0.        ]
# First features sample      : [ 0.67858523 -0.          0.         -1.080839    1.080839  ]

# %%
np.random.seed(0)
num_data = len(Y)
num_train = int(0.75 * num_data)
index = np.random.permutation(range(num_data))
feats_train = features[index[:num_train]]
Y_train = Y[index[:num_train]]
feats_val = features[index[num_train:]]
Y_val = Y[index[num_train:]]

# We need these later for plotting
X_train = X[index[:num_train]]
X_val = X[index[num_train:]]

# %%
num_qubits = 2
num_layers = 6

weights_init = 0.01 * np.random.randn(num_layers, num_qubits, 3, requires_grad=True)
bias_init = np.array(0.0, requires_grad=True)

# %%
from pennylane.optimize.momentum import MomentumOptimizer
from laws_sgd import LAWS

sampling_method = "lookahead"
#sampling_method = "lookaheadrandomsmaple"
#sampling_method = "lookmultiahead"


gradient_method = "default"
#gradient_method = "adam-like"

opt = LAWS(delta= 0.5,
           lookaround_optimizer=MomentumOptimizer, 
           lookaround_stepsize= 0.01,
           lookaround_loop=5,
           sampling_method = sampling_method,
           gradient_method = gradient_method)

batch_size = 5

cost_wssgd = []
train_acc_wssgd = []
val_acc_wssgd = []

kwargs = {"sample_batch_size":5,
          "feats_train":feats_train,
          "Y_train":Y_train,
          "lookahead":False,}

# train the variational classifier
weights = weights_init
bias = bias_init
for it in range(50):

    # Update the weights by one optimizer step
    batch_index = np.random.randint(0, num_train, (batch_size,))
    feats_train_batch = feats_train[batch_index]
    Y_train_batch = Y_train[batch_index]

    weights, bias, _, _ = opt.step(cost, 
                                   weights, 
                                   bias, 
                                   feats_train_batch, 
                                   Y_train_batch,
                                   **kwargs)
    
    # Compute predictions on train and validation set
    predictions_train = [np.sign(variational_classifier(weights, bias, f)) for f in feats_train]
    predictions_val = [np.sign(variational_classifier(weights, bias, f)) for f in feats_val]

    # Compute accuracy on train and validation set
    acc_train = accuracy(Y_train, predictions_train)
    acc_val = accuracy(Y_val, predictions_val)
    
    c = cost(weights, bias, features, Y)
    
    cost_wssgd.append(c)
    train_acc_wssgd.append(acc_train)
    val_acc_wssgd.append(acc_val)

    print(
        "Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
        "".format(it + 1, c, acc_train, acc_val)
    )
# Out:
# Iter:     1 | Cost: 1.1238466 | Acc train: 0.4533333 | Acc validation: 0.5600000
# Iter:     2 | Cost: 0.8577001 | Acc train: 0.7066667 | Acc validation: 0.6800000
# Iter:     3 | Cost: 1.0267474 | Acc train: 0.5200000 | Acc validation: 0.4400000
# Iter:     4 | Cost: 1.0195038 | Acc train: 0.5200000 | Acc validation: 0.4400000
# Iter:     5 | Cost: 0.7137752 | Acc train: 0.7466667 | Acc validation: 0.6800000
# Iter:     6 | Cost: 0.7242218 | Acc train: 0.7333333 | Acc validation: 0.7600000
# Iter:     7 | Cost: 0.7741296 | Acc train: 0.6400000 | Acc validation: 0.6400000
# Iter:     8 | Cost: 0.8435210 | Acc train: 0.5600000 | Acc validation: 0.6000000
# Iter:     9 | Cost: 0.6229907 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    10 | Cost: 0.5803146 | Acc train: 0.9333333 | Acc validation: 1.0000000
# Iter:    11 | Cost: 0.6556019 | Acc train: 0.6933333 | Acc validation: 0.7200000
# Iter:    12 | Cost: 0.9577409 | Acc train: 0.5333333 | Acc validation: 0.5600000
# Iter:    13 | Cost: 0.6618105 | Acc train: 0.6400000 | Acc validation: 0.6400000
# Iter:    14 | Cost: 0.4222150 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    15 | Cost: 0.3318158 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    16 | Cost: 0.2829750 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    17 | Cost: 0.2574196 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    18 | Cost: 0.2552046 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    19 | Cost: 0.2423581 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    20 | Cost: 0.2309250 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    21 | Cost: 0.2378274 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    22 | Cost: 0.2490492 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    23 | Cost: 0.2299585 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    24 | Cost: 0.2389415 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    25 | Cost: 0.2683556 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    26 | Cost: 0.2413738 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    27 | Cost: 0.2431308 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    28 | Cost: 0.2866059 | Acc train: 0.9466667 | Acc validation: 0.9200000
# Iter:    29 | Cost: 0.2988607 | Acc train: 0.9466667 | Acc validation: 0.9200000
# Iter:    30 | Cost: 0.2561769 | Acc train: 0.9733333 | Acc validation: 1.0000000
# Iter:    31 | Cost: 0.2352269 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    32 | Cost: 0.2491357 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    33 | Cost: 0.2358353 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    34 | Cost: 0.2432146 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    35 | Cost: 0.2866577 | Acc train: 0.9333333 | Acc validation: 0.9600000
# Iter:    36 | Cost: 0.3101056 | Acc train: 0.9333333 | Acc validation: 0.9200000
# Iter:    37 | Cost: 0.2395351 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    38 | Cost: 0.2311265 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    39 | Cost: 0.2419462 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    40 | Cost: 0.2767929 | Acc train: 0.9466667 | Acc validation: 1.0000000
# Iter:    41 | Cost: 0.2571853 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    42 | Cost: 0.2345609 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    43 | Cost: 0.2303007 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    44 | Cost: 0.2594203 | Acc train: 0.9733333 | Acc validation: 1.0000000
# Iter:    45 | Cost: 0.2598367 | Acc train: 0.9733333 | Acc validation: 1.0000000
# Iter:    46 | Cost: 0.2524530 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    47 | Cost: 0.2345694 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    48 | Cost: 0.2311554 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    49 | Cost: 0.2433180 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    50 | Cost: 0.2900251 | Acc train: 0.9333333 | Acc validation: 0.9200000

# %%
plt.figure()
cm = plt.cm.RdBu

# make data for decision regions
xx, yy = np.meshgrid(np.linspace(0.0, 1.5, 20), np.linspace(0.0, 1.5, 20))
X_grid = [np.array([x, y]) for x, y in zip(xx.flatten(), yy.flatten())]

# preprocess grid points like data inputs above
padding = 0.3 * np.ones((len(X_grid), 1))
X_grid = np.c_[np.c_[X_grid, padding], np.zeros((len(X_grid), 1))]  # pad each input
normalization = np.sqrt(np.sum(X_grid ** 2, -1))
X_grid = (X_grid.T / normalization).T  # normalize each input
features_grid = np.array(
    [get_angles(x) for x in X_grid]
)  # angles for state preparation are new features
predictions_grid = [variational_classifier(weights, bias, f) for f in features_grid]
Z = np.reshape(predictions_grid, xx.shape)

# plot decision regions
cnt = plt.contourf(
    xx, yy, Z, levels=np.arange(-1, 1.1, 0.1), cmap=cm, alpha=0.8, extend="both"
)
plt.contour(
    xx, yy, Z, levels=[0.0], colors=("black",), linestyles=("--",), linewidths=(0.8,)
)
plt.colorbar(cnt, ticks=[-1, 0, 1])

# plot data
plt.scatter(
    X_train[:, 0][Y_train == 1],
    X_train[:, 1][Y_train == 1],
    c="b",
    marker="o",
    edgecolors="k",
    label="class 1 train",
)
plt.scatter(
    X_val[:, 0][Y_val == 1],
    X_val[:, 1][Y_val == 1],
    c="b",
    marker="^",
    edgecolors="k",
    label="class 1 validation",
)
plt.scatter(
    X_train[:, 0][Y_train == -1],
    X_train[:, 1][Y_train == -1],
    c="r",
    marker="o",
    edgecolors="k",
    label="class -1 train",
)
plt.scatter(
    X_val[:, 0][Y_val == -1],
    X_val[:, 1][Y_val == -1],
    c="r",
    marker="^",
    edgecolors="k",
    label="class -1 validation",
)

plt.legend()
plt.savefig('wssgd_baseline.pdf')
plt.show()

# %% [markdown]
# ## WS-SGD with Look Around Random Sample

# %%
from sgd import GradientDescentOptimizer
from pennylane.optimize.momentum import MomentumOptimizer
from laws_sgd import LAWS

#sampling_method = "lookahead"
sampling_method = "lookaheadrandomsmaple"
#sampling_method = "lookmultiahead"

gradient_method = "default"

opt = LAWS(delta= 0.05,
           lookaround_optimizer=MomentumOptimizer, 
           lookaround_stepsize= 0.01,
           lookaround_loop=5,
           sampling_method = sampling_method,
           gradient_method = gradient_method,
           beta=0.9)
batch_size = 5

cost_laws_random = []
train_acc_laws_random = []
val_acc_laws_random = []

kwargs = {"sample_batch_size":5,
          "feats_train":feats_train,
          "Y_train":Y_train,
          "lookahead":False,}

# train the variational classifier
weights = weights_init
bias = bias_init
for it in range(50):

    # Update the weights by one optimizer step
    batch_index = np.random.randint(0, num_train, (batch_size,))
    feats_train_batch = feats_train[batch_index]
    Y_train_batch = Y_train[batch_index]

    weights, bias, _, _ = opt.step(cost, 
                                   weights, 
                                   bias, 
                                   feats_train_batch, 
                                   Y_train_batch,
                                   **kwargs)
    
    # Compute predictions on train and validation set
    predictions_train = [np.sign(variational_classifier(weights, bias, f)) for f in feats_train]
    predictions_val = [np.sign(variational_classifier(weights, bias, f)) for f in feats_val]

    # Compute accuracy on train and validation set
    acc_train = accuracy(Y_train, predictions_train)
    acc_val = accuracy(Y_val, predictions_val)
    
    c = cost(weights, bias, features, Y)
    
    cost_laws_random.append(c)
    train_acc_laws_random.append(acc_train)
    val_acc_laws_random.append(acc_val)

    print(
        "Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
        "".format(it + 1, c, acc_train, acc_val)
    )
# Out:
# Iter:     1 | Cost: 1.2210968 | Acc train: 0.4933333 | Acc validation: 0.5600000
# Iter:     2 | Cost: 0.8204270 | Acc train: 0.7333333 | Acc validation: 0.6800000
# Iter:     3 | Cost: 0.8218950 | Acc train: 0.5333333 | Acc validation: 0.4800000
# Iter:     4 | Cost: 0.8068934 | Acc train: 0.6666667 | Acc validation: 0.6400000
# Iter:     5 | Cost: 0.7375868 | Acc train: 0.8533333 | Acc validation: 0.9200000
# Iter:     6 | Cost: 0.7972619 | Acc train: 0.5333333 | Acc validation: 0.4400000
# Iter:     7 | Cost: 0.7036978 | Acc train: 0.6133333 | Acc validation: 0.6000000
# Iter:     8 | Cost: 0.6271487 | Acc train: 0.8800000 | Acc validation: 0.9200000
# Iter:     9 | Cost: 0.5666205 | Acc train: 0.9466667 | Acc validation: 1.0000000
# Iter:    10 | Cost: 0.5722758 | Acc train: 0.8533333 | Acc validation: 0.9200000
# Iter:    11 | Cost: 0.5649697 | Acc train: 0.7866667 | Acc validation: 0.8000000
# Iter:    12 | Cost: 0.3827253 | Acc train: 0.9733333 | Acc validation: 1.0000000
# Iter:    13 | Cost: 0.3613803 | Acc train: 0.9200000 | Acc validation: 0.8800000
# Iter:    14 | Cost: 0.2644311 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    15 | Cost: 0.2624856 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    16 | Cost: 0.2340822 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    17 | Cost: 0.2486018 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    18 | Cost: 0.2406709 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    19 | Cost: 0.2778128 | Acc train: 0.9866667 | Acc validation: 0.9200000
# Iter:    20 | Cost: 0.2334102 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    21 | Cost: 0.3040645 | Acc train: 0.9200000 | Acc validation: 0.9600000
# Iter:    22 | Cost: 0.2305113 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    23 | Cost: 0.2763811 | Acc train: 0.9866667 | Acc validation: 0.9200000
# Iter:    24 | Cost: 0.2671456 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    25 | Cost: 0.2300339 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    26 | Cost: 0.2477116 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    27 | Cost: 0.2444364 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    28 | Cost: 0.2368761 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    29 | Cost: 0.2324892 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    30 | Cost: 0.2317273 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    31 | Cost: 0.2417318 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    32 | Cost: 0.2352438 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    33 | Cost: 0.2315500 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    34 | Cost: 0.2321757 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    35 | Cost: 0.2344040 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    36 | Cost: 0.2345069 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    37 | Cost: 0.2295294 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    38 | Cost: 0.3156970 | Acc train: 0.9600000 | Acc validation: 0.8800000
# Iter:    39 | Cost: 0.2528048 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    40 | Cost: 0.2611294 | Acc train: 0.9733333 | Acc validation: 1.0000000
# Iter:    41 | Cost: 0.2997034 | Acc train: 0.9333333 | Acc validation: 0.9200000
# Iter:    42 | Cost: 0.2327368 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    43 | Cost: 0.2719094 | Acc train: 1.0000000 | Acc validation: 0.9600000
# Iter:    44 | Cost: 0.2319154 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    45 | Cost: 0.2750122 | Acc train: 0.9466667 | Acc validation: 1.0000000
# Iter:    46 | Cost: 0.2422286 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    47 | Cost: 0.2376998 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    48 | Cost: 0.2422405 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    49 | Cost: 0.2347428 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    50 | Cost: 0.2721867 | Acc train: 0.9466667 | Acc validation: 1.0000000

# %%
plt.figure()
cm = plt.cm.RdBu

# make data for decision regions
xx, yy = np.meshgrid(np.linspace(0.0, 1.5, 20), np.linspace(0.0, 1.5, 20))
X_grid = [np.array([x, y]) for x, y in zip(xx.flatten(), yy.flatten())]

# preprocess grid points like data inputs above
padding = 0.3 * np.ones((len(X_grid), 1))
X_grid = np.c_[np.c_[X_grid, padding], np.zeros((len(X_grid), 1))]  # pad each input
normalization = np.sqrt(np.sum(X_grid ** 2, -1))
X_grid = (X_grid.T / normalization).T  # normalize each input
features_grid = np.array(
    [get_angles(x) for x in X_grid]
)  # angles for state preparation are new features
predictions_grid = [variational_classifier(weights, bias, f) for f in features_grid]
Z = np.reshape(predictions_grid, xx.shape)

# plot decision regions
cnt = plt.contourf(
    xx, yy, Z, levels=np.arange(-1, 1.1, 0.1), cmap=cm, alpha=0.8, extend="both"
)
plt.contour(
    xx, yy, Z, levels=[0.0], colors=("black",), linestyles=("--",), linewidths=(0.8,)
)
plt.colorbar(cnt, ticks=[-1, 0, 1])

# plot data
plt.scatter(
    X_train[:, 0][Y_train == 1],
    X_train[:, 1][Y_train == 1],
    c="b",
    marker="o",
    edgecolors="k",
    label="class 1 train",
)
plt.scatter(
    X_val[:, 0][Y_val == 1],
    X_val[:, 1][Y_val == 1],
    c="b",
    marker="^",
    edgecolors="k",
    label="class 1 validation",
)
plt.scatter(
    X_train[:, 0][Y_train == -1],
    X_train[:, 1][Y_train == -1],
    c="r",
    marker="o",
    edgecolors="k",
    label="class -1 train",
)
plt.scatter(
    X_val[:, 0][Y_val == -1],
    X_val[:, 1][Y_val == -1],
    c="r",
    marker="^",
    edgecolors="k",
    label="class -1 validation",
)

plt.legend()
plt.savefig('wssgd_random_sample.pdf')
plt.show()

# %% [markdown]
# ## WS-SGD with Look Around Random Sample Large Batch

# %%
from sgd import GradientDescentOptimizer
from pennylane.optimize.momentum import MomentumOptimizer
from laws_sgd import LAWS

#sampling_method = "lookahead"
sampling_method = "lookaheadrandomsmaple"
#sampling_method = "lookmultiahead"

gradient_method = "default"

opt = LAWS(delta= 0.05,
           lookaround_optimizer=MomentumOptimizer, 
           lookaround_stepsize= 0.01,
           lookaround_loop=5,
           sampling_method = sampling_method,
           gradient_method = gradient_method,
           beta=0.9)
batch_size = 5

cost_laws_random_l = []
train_acc_laws_random_l = []
val_acc_laws_random_l = []

kwargs = {"sample_batch_size":15,
          "feats_train":feats_train,
          "Y_train":Y_train,
          "lookahead":False,}

# train the variational classifier
weights = weights_init
bias = bias_init
for it in range(50):

    # Update the weights by one optimizer step
    batch_index = np.random.randint(0, num_train, (batch_size,))
    feats_train_batch = feats_train[batch_index]
    Y_train_batch = Y_train[batch_index]

    weights, bias, _, _ = opt.step(cost, 
                                   weights, 
                                   bias, 
                                   feats_train_batch, 
                                   Y_train_batch,
                                   **kwargs)
    
    # Compute predictions on train and validation set
    predictions_train = [np.sign(variational_classifier(weights, bias, f)) for f in feats_train]
    predictions_val = [np.sign(variational_classifier(weights, bias, f)) for f in feats_val]

    # Compute accuracy on train and validation set
    acc_train = accuracy(Y_train, predictions_train)
    acc_val = accuracy(Y_val, predictions_val)
    
    c = cost(weights, bias, features, Y)
    
    cost_laws_random_l.append(c)
    train_acc_laws_random_l.append(acc_train)
    val_acc_laws_random_l.append(acc_val)

    print(
        "Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
        "".format(it + 1, c, acc_train, acc_val)
    )
# Out:
# Iter:     1 | Cost: 0.9747522 | Acc train: 0.4800000 | Acc validation: 0.5600000
# Iter:     2 | Cost: 0.8046536 | Acc train: 0.7333333 | Acc validation: 0.6800000
# Iter:     3 | Cost: 0.7224569 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:     4 | Cost: 0.8314881 | Acc train: 0.6400000 | Acc validation: 0.6400000
# Iter:     5 | Cost: 0.7196186 | Acc train: 0.8533333 | Acc validation: 0.9200000
# Iter:     6 | Cost: 0.8030656 | Acc train: 0.5200000 | Acc validation: 0.4400000
# Iter:     7 | Cost: 0.6680407 | Acc train: 0.9200000 | Acc validation: 0.9200000
# Iter:     8 | Cost: 0.6292133 | Acc train: 0.8266667 | Acc validation: 0.9200000
# Iter:     9 | Cost: 0.5721756 | Acc train: 0.8400000 | Acc validation: 0.9200000
# Iter:    10 | Cost: 0.4650205 | Acc train: 0.9466667 | Acc validation: 1.0000000
# Iter:    11 | Cost: 0.3853569 | Acc train: 0.9600000 | Acc validation: 1.0000000
# Iter:    12 | Cost: 0.2986801 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    13 | Cost: 0.2558864 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    14 | Cost: 0.2496453 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    15 | Cost: 0.2398169 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    16 | Cost: 0.2378714 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    17 | Cost: 0.2376147 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    18 | Cost: 0.2368377 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    19 | Cost: 0.2383952 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    20 | Cost: 0.2382808 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    21 | Cost: 0.2352563 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    22 | Cost: 0.2367059 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    23 | Cost: 0.2370703 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    24 | Cost: 0.2405598 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    25 | Cost: 0.2485381 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    26 | Cost: 0.2462524 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    27 | Cost: 0.2443464 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    28 | Cost: 0.2447694 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    29 | Cost: 0.2495108 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    30 | Cost: 0.2368560 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    31 | Cost: 0.2386268 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    32 | Cost: 0.2357412 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    33 | Cost: 0.2361742 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    34 | Cost: 0.2399405 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    35 | Cost: 0.2388454 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    36 | Cost: 0.2403104 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    37 | Cost: 0.2422764 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    38 | Cost: 0.2428015 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    39 | Cost: 0.2502656 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    40 | Cost: 0.2397965 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    41 | Cost: 0.2403851 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    42 | Cost: 0.2371804 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    43 | Cost: 0.2415051 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    44 | Cost: 0.2415554 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    45 | Cost: 0.2457217 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    46 | Cost: 0.2354602 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    47 | Cost: 0.2359151 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    48 | Cost: 0.2364065 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    49 | Cost: 0.2376656 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    50 | Cost: 0.2352188 | Acc train: 0.9866667 | Acc validation: 1.0000000

# %%
plt.figure()
cm = plt.cm.RdBu

# make data for decision regions
xx, yy = np.meshgrid(np.linspace(0.0, 1.5, 20), np.linspace(0.0, 1.5, 20))
X_grid = [np.array([x, y]) for x, y in zip(xx.flatten(), yy.flatten())]

# preprocess grid points like data inputs above
padding = 0.3 * np.ones((len(X_grid), 1))
X_grid = np.c_[np.c_[X_grid, padding], np.zeros((len(X_grid), 1))]  # pad each input
normalization = np.sqrt(np.sum(X_grid ** 2, -1))
X_grid = (X_grid.T / normalization).T  # normalize each input
features_grid = np.array(
    [get_angles(x) for x in X_grid]
)  # angles for state preparation are new features
predictions_grid = [variational_classifier(weights, bias, f) for f in features_grid]
Z = np.reshape(predictions_grid, xx.shape)

# plot decision regions
cnt = plt.contourf(
    xx, yy, Z, levels=np.arange(-1, 1.1, 0.1), cmap=cm, alpha=0.8, extend="both"
)
plt.contour(
    xx, yy, Z, levels=[0.0], colors=("black",), linestyles=("--",), linewidths=(0.8,)
)
plt.colorbar(cnt, ticks=[-1, 0, 1])

# plot data
plt.scatter(
    X_train[:, 0][Y_train == 1],
    X_train[:, 1][Y_train == 1],
    c="b",
    marker="o",
    edgecolors="k",
    label="class 1 train",
)
plt.scatter(
    X_val[:, 0][Y_val == 1],
    X_val[:, 1][Y_val == 1],
    c="b",
    marker="^",
    edgecolors="k",
    label="class 1 validation",
)
plt.scatter(
    X_train[:, 0][Y_train == -1],
    X_train[:, 1][Y_train == -1],
    c="r",
    marker="o",
    edgecolors="k",
    label="class -1 train",
)
plt.scatter(
    X_val[:, 0][Y_val == -1],
    X_val[:, 1][Y_val == -1],
    c="r",
    marker="^",
    edgecolors="k",
    label="class -1 validation",
)

plt.legend()
plt.savefig('wssgd_random_sample_large_batch.pdf')
plt.show()

# %%
from sgd import GradientDescentOptimizer
from pennylane.optimize.momentum import MomentumOptimizer
from laws_sgd import LAWS

#sampling_method = "lookahead"
#sampling_method = "lookaheadrandomsmaple"
sampling_method = "lookmultiahead"

gradient_method = "default"

opt = LAWS(delta= 0.5,
           lookaround_optimizer=MomentumOptimizer, 
           lookaround_stepsize= 0.01,
           lookaround_loop=32,
           sampling_method = sampling_method,
           gradient_method = gradient_method,
           sampling_stepsize=0.1)
batch_size = 5

cost_laws_mutlihead = []
train_acc_laws_mutlihead = []
val_acc_laws_mutlihead = []

kwargs = {"sample_batch_size":5,
          "feats_train":feats_train,
          "Y_train":Y_train,
          "lookahead":False,}

# train the variational classifier
weights = weights_init
bias = bias_init
for it in range(50):

    # Update the weights by one optimizer step
    batch_index = np.random.randint(0, num_train, (batch_size,))
    feats_train_batch = feats_train[batch_index]
    Y_train_batch = Y_train[batch_index]

    weights, bias, _, _ = opt.step(cost, 
                                   weights, 
                                   bias, 
                                   feats_train_batch, 
                                   Y_train_batch,
                                   **kwargs)
    # Compute predictions on train and validation set
    predictions_train = [np.sign(variational_classifier(weights, bias, f)) for f in feats_train]
    predictions_val = [np.sign(variational_classifier(weights, bias, f)) for f in feats_val]

    # Compute accuracy on train and validation set
    acc_train = accuracy(Y_train, predictions_train)
    acc_val = accuracy(Y_val, predictions_val)
    
    c = cost(weights, bias, features, Y)
    
    cost_laws_mutlihead.append(c)
    train_acc_laws_mutlihead.append(acc_train)
    val_acc_laws_mutlihead.append(acc_val)

    print(
        "Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
        "".format(it + 1, c, acc_train, acc_val)
    )
# Out:
# Iter:     1 | Cost: 1.3459260 | Acc train: 0.4933333 | Acc validation: 0.5600000
# Iter:     2 | Cost: 1.1315747 | Acc train: 0.4666667 | Acc validation: 0.5600000
# Iter:     3 | Cost: 1.0098519 | Acc train: 0.4933333 | Acc validation: 0.5600000
# Iter:     4 | Cost: 0.9042587 | Acc train: 0.5466667 | Acc validation: 0.6400000
# Iter:     5 | Cost: 0.8545884 | Acc train: 0.5866667 | Acc validation: 0.7600000
# Iter:     6 | Cost: 0.8153116 | Acc train: 0.7200000 | Acc validation: 0.8000000
# Iter:     7 | Cost: 0.7941327 | Acc train: 0.7733333 | Acc validation: 0.8800000
# Iter:     8 | Cost: 0.7831386 | Acc train: 0.7733333 | Acc validation: 0.8400000
# Iter:     9 | Cost: 0.7639023 | Acc train: 0.8000000 | Acc validation: 0.9600000
# Iter:    10 | Cost: 0.7528688 | Acc train: 0.8000000 | Acc validation: 0.9600000
# Iter:    11 | Cost: 0.7492823 | Acc train: 0.8266667 | Acc validation: 0.8800000
# Iter:    12 | Cost: 0.7435343 | Acc train: 0.8133333 | Acc validation: 0.8400000
# Iter:    13 | Cost: 0.7302957 | Acc train: 0.8400000 | Acc validation: 1.0000000
# Iter:    14 | Cost: 0.7239766 | Acc train: 0.8533333 | Acc validation: 1.0000000
# Iter:    15 | Cost: 0.7193646 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    16 | Cost: 0.7163700 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    17 | Cost: 0.7116217 | Acc train: 0.8266667 | Acc validation: 0.9600000
# Iter:    18 | Cost: 0.7113560 | Acc train: 0.8133333 | Acc validation: 0.9200000
# Iter:    19 | Cost: 0.7099969 | Acc train: 0.8133333 | Acc validation: 0.9200000
# Iter:    20 | Cost: 0.7105005 | Acc train: 0.8133333 | Acc validation: 0.9200000
# Iter:    21 | Cost: 0.7067373 | Acc train: 0.8133333 | Acc validation: 0.9200000
# Iter:    22 | Cost: 0.7007409 | Acc train: 0.8266667 | Acc validation: 0.9600000
# Iter:    23 | Cost: 0.6978699 | Acc train: 0.8800000 | Acc validation: 0.9600000
# Iter:    24 | Cost: 0.6959151 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    25 | Cost: 0.6949176 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    26 | Cost: 0.6907658 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    27 | Cost: 0.6888994 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    28 | Cost: 0.6858236 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    29 | Cost: 0.6830416 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    30 | Cost: 0.6829479 | Acc train: 0.9066667 | Acc validation: 0.9600000
# Iter:    31 | Cost: 0.6825303 | Acc train: 0.9200000 | Acc validation: 0.9200000
# Iter:    32 | Cost: 0.6746235 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    33 | Cost: 0.6716074 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    34 | Cost: 0.6689299 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    35 | Cost: 0.6652687 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    36 | Cost: 0.6622817 | Acc train: 0.9333333 | Acc validation: 1.0000000
# Iter:    37 | Cost: 0.6581870 | Acc train: 0.9333333 | Acc validation: 1.0000000
# Iter:    38 | Cost: 0.6571956 | Acc train: 0.9066667 | Acc validation: 0.9200000
# Iter:    39 | Cost: 0.6494455 | Acc train: 0.9200000 | Acc validation: 0.9600000
# Iter:    40 | Cost: 0.6455475 | Acc train: 0.9066667 | Acc validation: 1.0000000
# Iter:    41 | Cost: 0.6384889 | Acc train: 0.9333333 | Acc validation: 1.0000000
# Iter:    42 | Cost: 0.6332134 | Acc train: 0.9466667 | Acc validation: 1.0000000
# Iter:    43 | Cost: 0.6295774 | Acc train: 0.9066667 | Acc validation: 1.0000000
# Iter:    44 | Cost: 0.6221744 | Acc train: 0.9333333 | Acc validation: 0.9600000
# Iter:    45 | Cost: 0.6155247 | Acc train: 0.9333333 | Acc validation: 0.9600000
# Iter:    46 | Cost: 0.6084577 | Acc train: 0.9466667 | Acc validation: 1.0000000
# Iter:    47 | Cost: 0.6021340 | Acc train: 0.9200000 | Acc validation: 0.9600000
# Iter:    48 | Cost: 0.5929894 | Acc train: 0.9466667 | Acc validation: 1.0000000
# Iter:    49 | Cost: 0.5848126 | Acc train: 0.9466667 | Acc validation: 1.0000000
# Iter:    50 | Cost: 0.5754621 | Acc train: 0.9333333 | Acc validation: 0.9600000

# %%
plt.figure()
cm = plt.cm.RdBu

# make data for decision regions
xx, yy = np.meshgrid(np.linspace(0.0, 1.5, 20), np.linspace(0.0, 1.5, 20))
X_grid = [np.array([x, y]) for x, y in zip(xx.flatten(), yy.flatten())]

# preprocess grid points like data inputs above
padding = 0.3 * np.ones((len(X_grid), 1))
X_grid = np.c_[np.c_[X_grid, padding], np.zeros((len(X_grid), 1))]  # pad each input
normalization = np.sqrt(np.sum(X_grid ** 2, -1))
X_grid = (X_grid.T / normalization).T  # normalize each input
features_grid = np.array(
    [get_angles(x) for x in X_grid]
)  # angles for state preparation are new features
predictions_grid = [variational_classifier(weights, bias, f) for f in features_grid]
Z = np.reshape(predictions_grid, xx.shape)

# plot decision regions
cnt = plt.contourf(
    xx, yy, Z, levels=np.arange(-1, 1.1, 0.1), cmap=cm, alpha=0.8, extend="both"
)
plt.contour(
    xx, yy, Z, levels=[0.0], colors=("black",), linestyles=("--",), linewidths=(0.8,)
)
plt.colorbar(cnt, ticks=[-1, 0, 1])

# plot data
plt.scatter(
    X_train[:, 0][Y_train == 1],
    X_train[:, 1][Y_train == 1],
    c="b",
    marker="o",
    edgecolors="k",
    label="class 1 train",
)
plt.scatter(
    X_val[:, 0][Y_val == 1],
    X_val[:, 1][Y_val == 1],
    c="b",
    marker="^",
    edgecolors="k",
    label="class 1 validation",
)
plt.scatter(
    X_train[:, 0][Y_train == -1],
    X_train[:, 1][Y_train == -1],
    c="r",
    marker="o",
    edgecolors="k",
    label="class -1 train",
)
plt.scatter(
    X_val[:, 0][Y_val == -1],
    X_val[:, 1][Y_val == -1],
    c="r",
    marker="^",
    edgecolors="k",
    label="class -1 validation",
)

plt.legend()
plt.savefig('wssgd_random_sample_Multiple.pdf')
plt.show()

# %%
from sgd import GradientDescentOptimizer
from pennylane.optimize.momentum import MomentumOptimizer
from laws_sgd import LAWS

#sampling_method = "lookahead"
#sampling_method = "lookaheadrandomsmaple"
sampling_method = "lookmultiahead"

gradient_method = "default"

opt = LAWS(delta= 0.5,
           lookaround_optimizer=MomentumOptimizer, 
           lookaround_stepsize= 0.01,
           lookaround_loop=8,
           sampling_method = sampling_method,
           gradient_method = gradient_method,
           sampling_stepsize=0.1)
batch_size = 5

cost_laws_mutlihead_l = []
train_acc_laws_mutlihead_l = []
val_acc_laws_mutlihead_l = []

kwargs = {"sample_batch_size":32,
          "feats_train":feats_train,
          "Y_train":Y_train,
          "lookahead":False,}

# train the variational classifier
weights = weights_init
bias = bias_init
for it in range(50):

    # Update the weights by one optimizer step
    batch_index = np.random.randint(0, num_train, (batch_size,))
    feats_train_batch = feats_train[batch_index]
    Y_train_batch = Y_train[batch_index]

    weights, bias, _, _ = opt.step(cost, 
                                   weights, 
                                   bias, 
                                   feats_train_batch, 
                                   Y_train_batch,
                                   **kwargs)
    # Compute predictions on train and validation set
    predictions_train = [np.sign(variational_classifier(weights, bias, f)) for f in feats_train]
    predictions_val = [np.sign(variational_classifier(weights, bias, f)) for f in feats_val]

    # Compute accuracy on train and validation set
    acc_train = accuracy(Y_train, predictions_train)
    acc_val = accuracy(Y_val, predictions_val)
    
    c = cost(weights, bias, features, Y)
    
    cost_laws_mutlihead_l.append(c)
    train_acc_laws_mutlihead_l.append(acc_train)
    val_acc_laws_mutlihead_l.append(acc_val)

    print(
        "Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
        "".format(it + 1, c, acc_train, acc_val)
    )
# Out:
# Iter:     1 | Cost: 1.4277059 | Acc train: 0.4933333 | Acc validation: 0.5600000
# Iter:     2 | Cost: 1.2484519 | Acc train: 0.4800000 | Acc validation: 0.5600000
# Iter:     3 | Cost: 1.0620100 | Acc train: 0.4666667 | Acc validation: 0.5600000
# Iter:     4 | Cost: 0.9303957 | Acc train: 0.5200000 | Acc validation: 0.6000000
# Iter:     5 | Cost: 0.8586740 | Acc train: 0.6400000 | Acc validation: 0.7600000
# Iter:     6 | Cost: 0.8269663 | Acc train: 0.7600000 | Acc validation: 0.8400000
# Iter:     7 | Cost: 0.8081025 | Acc train: 0.7733333 | Acc validation: 0.8400000
# Iter:     8 | Cost: 0.7904736 | Acc train: 0.7600000 | Acc validation: 0.8400000
# Iter:     9 | Cost: 0.7757244 | Acc train: 0.8000000 | Acc validation: 0.8400000
# Iter:    10 | Cost: 0.7631449 | Acc train: 0.8000000 | Acc validation: 0.8400000
# Iter:    11 | Cost: 0.7497001 | Acc train: 0.8400000 | Acc validation: 0.9200000
# Iter:    12 | Cost: 0.7396388 | Acc train: 0.8400000 | Acc validation: 1.0000000
# Iter:    13 | Cost: 0.7317384 | Acc train: 0.8133333 | Acc validation: 0.9600000
# Iter:    14 | Cost: 0.7265498 | Acc train: 0.8266667 | Acc validation: 0.9600000
# Iter:    15 | Cost: 0.7224197 | Acc train: 0.8533333 | Acc validation: 0.9600000
# Iter:    16 | Cost: 0.7193260 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    17 | Cost: 0.7160666 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    18 | Cost: 0.7133025 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    19 | Cost: 0.7099750 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    20 | Cost: 0.7074859 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    21 | Cost: 0.7051339 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    22 | Cost: 0.7030092 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    23 | Cost: 0.7007701 | Acc train: 0.8533333 | Acc validation: 0.9600000
# Iter:    24 | Cost: 0.6986137 | Acc train: 0.8800000 | Acc validation: 1.0000000
# Iter:    25 | Cost: 0.6979239 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    26 | Cost: 0.6963709 | Acc train: 0.8800000 | Acc validation: 0.9600000
# Iter:    27 | Cost: 0.6953020 | Acc train: 0.8933333 | Acc validation: 0.9200000
# Iter:    28 | Cost: 0.6942182 | Acc train: 0.9200000 | Acc validation: 0.9200000
# Iter:    29 | Cost: 0.6899921 | Acc train: 0.8933333 | Acc validation: 0.9600000
# Iter:    30 | Cost: 0.6860601 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    31 | Cost: 0.6834902 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    32 | Cost: 0.6810466 | Acc train: 0.9066667 | Acc validation: 1.0000000
# Iter:    33 | Cost: 0.6778133 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    34 | Cost: 0.6747371 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    35 | Cost: 0.6714402 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    36 | Cost: 0.6680619 | Acc train: 0.8933333 | Acc validation: 1.0000000
# Iter:    37 | Cost: 0.6658376 | Acc train: 0.9200000 | Acc validation: 0.9600000
# Iter:    38 | Cost: 0.6624150 | Acc train: 0.9200000 | Acc validation: 0.9600000
# Iter:    39 | Cost: 0.6572628 | Acc train: 0.9200000 | Acc validation: 0.9600000
# Iter:    40 | Cost: 0.6525210 | Acc train: 0.9333333 | Acc validation: 1.0000000
# Iter:    41 | Cost: 0.6480573 | Acc train: 0.9200000 | Acc validation: 1.0000000
# Iter:    42 | Cost: 0.6433888 | Acc train: 0.9200000 | Acc validation: 1.0000000
# Iter:    43 | Cost: 0.6382628 | Acc train: 0.9333333 | Acc validation: 1.0000000
# Iter:    44 | Cost: 0.6331486 | Acc train: 0.9333333 | Acc validation: 1.0000000
# Iter:    45 | Cost: 0.6277817 | Acc train: 0.9200000 | Acc validation: 0.9600000
# Iter:    46 | Cost: 0.6222675 | Acc train: 0.9200000 | Acc validation: 0.9600000
# Iter:    47 | Cost: 0.6154548 | Acc train: 0.9200000 | Acc validation: 0.9600000
# Iter:    48 | Cost: 0.6080189 | Acc train: 0.9333333 | Acc validation: 0.9600000
# Iter:    49 | Cost: 0.6011137 | Acc train: 0.9200000 | Acc validation: 0.9200000
# Iter:    50 | Cost: 0.5937509 | Acc train: 0.9066667 | Acc validation: 0.8800000

# %%
plt.style.use("seaborn")
plt.plot(cost_wssgd, "g", label="Warm-start Optimizer (Baseline)")
plt.plot(cost_laws_random, "b", label="Random Sampling (Sample Batch = 5)")
plt.plot(cost_laws_random_l, "r", label="Random Sampling (Sample Batch = 15)")

plt.plot(cost_laws_mutlihead, "k", label="Multiple Random Sampling")
plt.plot(cost_laws_mutlihead_l, "y", label="Multiple Random Sampling (Sample Batch = 32)")

plt.ylabel("Cost function value")
plt.xlabel("Optimization steps")
plt.legend()
plt.savefig('cost_variant.pdf')
plt.show()

# %%
plt.style.use("seaborn")

plt.plot(train_acc_wssgd, "g", label="Warm-start Optimizer")
plt.plot(train_acc_laws_random, "b", label="Random Sampling (Sample Batch = 5)")
plt.plot(train_acc_laws_random_l, "r", label="Random Sampling (Sample Batch = 15)")
 
plt.plot(train_acc_laws_mutlihead, "k", label="Multiple Random Sampling")

plt.plot(train_acc_laws_mutlihead_l, "y", label="Multiple Random Sampling (Sample Batch = 32)")


plt.ylabel("Train Acc")
plt.xlabel("Optimization steps")
plt.legend()
plt.savefig('train_acc_variant.pdf')
plt.show()

# %%
plt.style.use("seaborn")

plt.plot(val_acc_wssgd, "g", label="Warm-start Optimizer")
plt.plot(val_acc_laws_random, "b", label="Random Sampling (Sample Batch = 5)")
plt.plot(val_acc_laws_random_l, "r", label="Random Sampling (Sample Batch = 15)")

plt.plot(val_acc_laws_mutlihead, "k", label="Multiple Random Sampling")
plt.plot(val_acc_laws_mutlihead_l, "y", label="Multiple Random Sampling (Sample Batch = 32)")

plt.ylabel("validation Acc")
plt.xlabel("Optimization steps")
plt.legend()
plt.savefig('val_acc_variant.pdf')
plt.show()
